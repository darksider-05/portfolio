# %% [markdown]
# <br>
# this is the image sizing that will be used for taking the screenshots.
#
# <br>
# <br>
#
# | Variant                     | Target         | Size           |
# | --------------------------- | -------------- | -------------- |
# | **Desktop**                 | Large screens  | **1200 × 675** |
# | **Tablet / Narrow desktop** | Medium screens | **900 × 506**  |
# | **Mobile**                  | Phones         | **390 × 844**  |

# %% [markdown]
# these are candidates for showcase:
#
# 1. Ecovision App --done
# 2. Live Text --done
# 3. MineSweeper --done
# 4. FlipClock --done
# 5. Portfolio -----------------------
# 6. CodePanel  --done
#
# * designing the backend server that collects the user messages and forwards them to me. --done
# * the contact-me form is functional

# %% [markdown]
# todo:
# *   need to update the project selector  -- done? maybe

# %% [markdown]
# `flutter run -d Edge --no-web-resources-cdn --hot`
#
# this is the code to run on browser offline
